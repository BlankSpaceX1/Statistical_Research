# %%
import pandas as pd 
import numpy as np 
from bs4 import BeautifulSoup as bs 
import matplotlib.pyplot as plt 
import seaborn as sns 
import requests

# %%
pd.set_option("display.max_columns", None)

# %%
holder = pd.read_csv('/Users/emmanuely/Desktop/CodeFolder/Statistical_Research/Data Folder/international-international-friendlies-matches-2024-to-2024-stats.csv')

# %%
holder
# Out:
#       timestamp               date_GMT      status  attendance home_team_name  \
# 0    1704085200   Jan 01 2024 - 5:00am    complete         NaN          Japan
# 1    1704115800   Jan 01 2024 - 1:30pm    complete         NaN          China
# 2    1704200400   Jan 02 2024 - 1:00pm    complete         NaN      Indonesia
# 3    1704369600  Jan 04 2024 - 12:00pm    complete         NaN      Hong Kong
# 4    1704375000   Jan 04 2024 - 1:30pm    complete         NaN   Saudi Arabia
# ..          ...                    ...         ...         ...            ...
# 273  1731585600  Nov 14 2024 - 12:00pm  incomplete         NaN      Hong Kong
# 274  1731607200   Nov 14 2024 - 6:00pm  incomplete         NaN          Malta
# 275  1731974400  Nov 19 2024 - 12:00am  incomplete         NaN          India
# 276  1732017600  Nov 19 2024 - 12:00pm  incomplete         NaN      Hong Kong
# 277  1732045500   Nov 19 2024 - 7:45pm  incomplete         NaN      Gibraltar
#
# ...
